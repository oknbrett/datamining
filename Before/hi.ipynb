# %% [markdown]
# # First step my brother
#
# We are going to do something idk
#
# ## Data loading

# %%
import pandas as pd

url = "hi.ipynb 271124_IDBC_W7_5_S1_R11-2024-11-27_15-21-34.csv"
df = pd.read_csv(url)
df1 = pd.read_excel

print(df.head(15))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 import pandas as pd
#       3 url = "hi.ipynb 271124_IDBC_W7_5_S1_R11-2024-11-27_15-21-34.csv"
# ----> 4 df = pd.read_csv(url)
#       5 df1 = pd.read_excel
#       7 print(df.head(15))
#
# ...

# %%
import pandas as pd

# Correct file path (adjust as needed)
file_path = "271124_IDBC_W7_5_S1_R11-2024-11-27_15-21-34.csv"  

# Read the CSV file
df = pd.read_csv(file_path)

# Print the first 15 rows
print(df.head(15))
# Out:
#     secondsElapsed  wristMotion_rotationRateX  wristMotion_rotationRateY  \
# 0             0.00                  -0.000149                  -0.039282
# 1             0.01                  -0.074713                  -0.056091
# 2             0.02                  -0.109207                  -0.058646
# 3             0.03                  -0.106163                  -0.061258
# 4             0.04                  -0.093331                  -0.044773
# 5             0.05                  -0.087171                  -0.036282
# 6             0.06                  -0.070102                  -0.036288
# 7             0.07                  -0.021063                  -0.010705
# 8             0.08                   0.029794                   0.019996
# 9             0.09                   0.032530                   0.024616
# 10            0.10                  -0.023798                   0.009978
# 11            0.11                  -0.096096                  -0.006153
# ...

# %%
import pandas as pd

# Load the CSV file
file_path = "271124_IDBC_W7_5_S1_R11-2024-11-27_15-21-34.csv"
df = pd.read_csv(file_path)

# Filter out first 1.5 seconds and last 1.5 seconds
df_filtered = df[(df["secondsElapsed"] >= 1.5) & (df["secondsElapsed"] <= df["secondsElapsed"].max() - 1.5)]

# Print first 15 rows after filtering
print(df_filtered.head(15))
# Out:
#      secondsElapsed  wristMotion_rotationRateX  wristMotion_rotationRateY  \
# 150            1.50                   0.628885                   0.166484
# 151            1.51                   0.798432                   0.192165
# 152            1.52                   0.866484                   0.246474
# 153            1.53                   0.867769                   0.267997
# 154            1.54                   0.881803                   0.284104
# 155            1.55                   0.820455                   0.269976
# 156            1.56                   0.761589                   0.260713
# 157            1.57                   0.806289                   0.261883
# 158            1.58                   0.660177                   0.246373
# 159            1.59                   0.431735                   0.264516
# 160            1.60                   0.242871                   0.190894
# 161            1.61                  -0.094051                   0.168312
# ...
